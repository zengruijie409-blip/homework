# %%
# 作业1：显示并保存 train_images[6000]
import matplotlib.pyplot as plt
from tensorflow import keras
import numpy as np
import os

# 1. 载入 MNIST 数据
(mnist_train_images, mnist_train_labels), (mnist_test_images, mnist_test_labels) = keras.datasets.mnist.load_data()

# 确认形状
print("train_images shape:", mnist_train_images.shape)   # (60000, 28, 28)
print("train_labels shape:", mnist_train_labels.shape)

# 2. 选择第 6000 张图（索引从 0 开始）
idx = 6000
img = mnist_train_images[idx]
label = mnist_train_labels[idx]
print(f"index={idx}, label={label}")

# 3. 显示图片（在 notebook 中会显示）
plt.figure(figsize=(4,4))
plt.imshow(img, cmap='gray')
plt.title(f"train_images[{idx}]  label={label}")
plt.axis('off')

# 4. 保存截图为 PNG（当前目录下）
out_dir = "assignment1_output"
os.makedirs(out_dir, exist_ok=True)
out_path = os.path.join(out_dir, f"train_image_{idx}.png")
plt.savefig(out_path, bbox_inches='tight', pad_inches=0.1)
print("Saved image to:", out_path)

# 如果在本地运行，下一行不会做额外事（仅展示）
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# train_images shape: (60000, 28, 28)
# train_labels shape: (60000,)
# index=6000, label=6
# Saved image to: assignment1_output/train_image_6000.png

# %%
import matplotlib.pyplot as plt
from tensorflow import keras
import numpy as np
import os

# 1. 载入 MNIST 数据
(train_images, train_labels), (_, _) = keras.datasets.mnist.load_data()

# 需要显示的索引
indexes = [1000, 2000, 3000, 4000]

# 2. 创建输出目录
out_dir = "assignment2_output"
os.makedirs(out_dir, exist_ok=True)

# 3. 创建 2x2 subplot（ax1, ax2, ax3, ax4）
fig, axes = plt.subplots(1, 4, figsize=(16, 4))

for i, idx in enumerate(indexes):
    ax = axes[i]
    img = train_images[idx]
    label = train_labels[idx]

    ax.imshow(img, cmap='gray')
    ax.set_title(f"train_images[{idx}]\nlabel={label}")
    ax.axis('off')

# 4. 保存整张图为 PNG
save_path = os.path.join(out_dir, "task2_subplot.png")
plt.savefig(save_path, bbox_inches='tight', pad_inches=0.1)

print("任务2图像已保存:", save_path)

# 5. 显示图像（Jupyter/Colab 可视化）
plt.show()
# Out:
# 任务2图像已保存: assignment2_output/task2_subplot.png

# %%
import matplotlib.pyplot as plt
from tensorflow import keras
import os

# 1. 载入 MNIST 数据
(train_images, train_labels), _ = keras.datasets.mnist.load_data()

# 2. 要显示的四个索引
indexes = [1000, 2000, 3000, 4000]

# 3. 输出目录
out_dir = "assignment2_output"
os.makedirs(out_dir, exist_ok=True)

# 4. 建立 1×4 subplot（ax1 ~ ax4）
fig, axes = plt.subplots(1, 4, figsize=(16, 4))

for i, idx in enumerate(indexes):
    ax = axes[i]
    img = train_images[idx]
    label = train_labels[idx]

    ax.imshow(img, cmap="gray")
    ax.set_title(f"train_image[{idx}]\nlabel={label}")
    ax.axis("off")

# 5. 保存图像
save_path = os.path.join(out_dir, "assignment2_subplot.png")
plt.savefig(save_path, bbox_inches='tight', pad_inches=0.1)
print("作业2图像已保存：", save_path)

plt.show()
# Out:
# 作业2图像已保存： assignment2_output/assignment2_subplot.png

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# 1. MNIST 数据
(train_images, train_labels), _ = keras.datasets.mnist.load_data()

# 数据 reshape + 归一化
train_images = train_images.reshape((60000, 28*28)).astype("float32") / 255.0

# 2. 搭建模型（隐藏层从 256 改 128）
model = keras.Sequential([
    layers.Dense(128, activation='relu', input_shape=(784,)),  # ★ input_shape 必须加!
    layers.Dense(10, activation='softmax')
])

# 3. 打印模型结构
print("\n===== MODEL SUMMARY =====\n")
model.summary()
# Out:
# ===== MODEL SUMMARY =====
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_2 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# 1. MNIST 数据
(train_images, train_labels), (test_images, test_labels) = keras.datasets.mnist.load_data()

# 数据 reshape + 归一化
train_images = train_images.reshape((60000, 784)).astype("float32") / 255.0
test_images = test_images.reshape((10000, 784)).astype("float32") / 255.0

# 2. 模型隐藏层：128（来自作业 3）
model = keras.Sequential([
    keras.Input(shape=(784,)),         # 正确的输入方式
    layers.Dense(128, activation='relu'),
    layers.Dense(10, activation='softmax')
])

# 3. 使用 SGD 代替 Adam
model.compile(
    optimizer=keras.optimizers.SGD(learning_rate=0.01),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# 4. 打印模型结构（编译后）
print("\n===== MODEL SUMMARY (SGD Optimizer) =====\n")
model.summary()

print("\n===== MODEL COMPILED WITH SGD =====")
print(model.optimizer)
# Out:
# ===== MODEL SUMMARY (SGD Optimizer) =====
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 128)            │       100,480 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 101,770 (397.54 KB)
#  Trainable params: 101,770 (397.54 KB)
#  Non-trainable params: 0 (0.00 B)
# ===== MODEL COMPILED WITH SGD =====
# <keras.src.optimizers.sgd.SGD object at 0x7bd9667c6ae0>

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# 1. MNIST 数据
(train_images, train_labels), (test_images, test_labels) = keras.datasets.mnist.load_data()

# reshape + 归一化
train_images = train_images.reshape((60000, 784)).astype("float32") / 255.0
test_images = test_images.reshape((10000, 784)).astype("float32") / 255.0

# 2. 定义模型
def create_model():
    model = keras.Sequential([
        keras.Input(shape=(784,)),
        layers.Dense(128, activation="relu"),
        layers.Dense(10, activation="softmax")
    ])

    model.compile(
        optimizer=keras.optimizers.SGD(learning_rate=0.01),
        loss="sparse_categorical_crossentropy",
        metrics=["accuracy"]       # ★ 使用 accuracy 作为指标
    )
    return model


# -------- 训练 epochs=2 --------
model_2 = create_model()
print("\n===== Training with epochs=2 =====")
history_2 = model_2.fit(train_images, train_labels, epochs=2, batch_size=32, verbose=1)
acc_2 = history_2.history["accuracy"][-1]


# -------- 训练 epochs=5 --------
model_5 = create_model()
print("\n===== Training with epochs=5 =====")
history_5 = model_5.fit(train_images, train_labels, epochs=5, batch_size=32, verbose=1)
acc_5 = history_5.history["accuracy"][-1]


# 结果打印
print("\n===== RESULTS =====")
print(f"Accuracy (epochs=2): {acc_2:.4f}")
print(f"Accuracy (epochs=5): {acc_5:.4f}")
# Out:
# ===== Training with epochs=2 =====
# Epoch 1/2
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.7432 - loss: 1.0175
# Epoch 2/2
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 8s 3ms/step - accuracy: 0.9007 - loss: 0.3552
#
# ===== Training with epochs=5 =====
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7425 - loss: 1.0056
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9005 - loss: 0.3597
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.9145 - loss: 0.3014
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9265 - loss: 0.2654
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 7s 4ms/step - accuracy: 0.9301 - loss: 0.2477
#
# ===== RESULTS =====
# Accuracy (epochs=2): 0.9053
# Accuracy (epochs=5): 0.9330
